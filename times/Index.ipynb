# %% [markdown]
# # Welcome to Jupyter!

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.rand(10,3),columns=['Acol','Ccol','Bcol'])
x = df[['Acol', 'Bcol']].to_records()
y = df[['Ccol']].to_records()

res[5]

obj = {
    'data': x,
    'target': y
}

obj
# Out:
# {'data': rec.array([(0, 0.41162464, 0.63698333), (1, 0.88541659, 0.37994293),
#             (2, 0.15277256, 0.77228856), (3, 0.77659866, 0.29912952),
#             (4, 0.42086512, 0.77526599), (5, 0.28063716, 0.10960592),
#             (6, 0.08131325, 0.43754541), (7, 0.50707632, 0.1987405 ),
#             (8, 0.00706464, 0.18878592), (9, 0.09079038, 0.90915247)],
#            dtype=[('index', '<i8'), ('Acol', '<f8'), ('Bcol', '<f8')]),
#  'target': rec.array([(0, 0.00599924), (1, 0.01832049), (2, 0.58308344),
#             (3, 0.57828968), (4, 0.36481671), (5, 0.27112037),
#             (6, 0.80870468), (7, 0.30271573), (8, 0.52170991),
#             (9, 0.82822861)],
#            dtype=[('index', '<i8'), ('Ccol', '<f8')])}
